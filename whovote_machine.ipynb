# %%
# Import modules
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
vote_df = pd.read_csv(
    Path('C:/Users/isabe/OneDrive/Documents/GitHub/Project-4/for_lear.csv')   
)
vote_df.head()
# Out:
#    Unnamed: 0         V201022      V201228  V201507x V202637     V202355  \
# 0           0  Have not voted   Republican        46       3        City
# 1           1  Have not voted        Other        37       3      Suburb
# 2           2  Have not voted  Independent        40       3      Suburb
# 3           3  Have not voted   Republican        41       3  Small town
# 4           4  Have not voted  Independent        72       3        City
#
#            V201114                                           V201549x  \
# 0  Right direction                                           Hispanic
# 1      Wrong track  Asian or Native Hawaiian/other Pacific Islande...
# 2      Wrong track                                White, non-Hispanic
# 3      Wrong track  Asian or Native Hawaiian/other Pacific Islande...
# 4      Wrong track  Native American/Alaska Native or other race, n...
#
#            V202468x                               V201020  ...  \
# ...

# %%
x = vote_df.drop(columns=['V201022','V201020','V201576','V201220','V201105','V202073','V201200','V201201','V202436','V202435','V201227'])
y = vote_df['V202073']

# %%
x.head()
# Out:
#    Unnamed: 0      V201228  V201507x V202637     V202355          V201114  \
# 0           0   Republican        46       3        City  Right direction
# 1           1        Other        37       3      Suburb      Wrong track
# 2           2  Independent        40       3      Suburb      Wrong track
# 3           3   Republican        41       3  Small town      Wrong track
# 4           4  Independent        72       3        City      Wrong track
#
#                                             V201549x          V202468x  \
# 0                                           Hispanic  $175,000-249,999
# 1  Asian or Native Hawaiian/other Pacific Islande...    $70,000-74,999
# 2                                White, non-Hispanic  $100,000-109,999
# 3  Asian or Native Hawaiian/other Pacific Islande...    $35,000-39,999
# 4  Native American/Alaska Native or other race, n...  $250,000 or more
#
#    V201151  V201152
# 0        0      100
# 1        0        0
# 2       65        0
# ...

# %%
#y = y.drop(y[y == -1].index)
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    0
# 4    1
# Name: V202073, dtype: object

# %%
dummy_df = x.drop(columns=['V201507x','V201151','V201152'])
dummy_df = pd.get_dummies(dummy_df)

# %%
x = dummy_df

# %%
x.head()
# Out:
#    Unnamed: 0  V201228_Democrat  V201228_Do not know  V201228_Independent  \
# 0           0             False                False                False
# 1           1             False                False                False
# 2           2             False                False                 True
# 3           3             False                False                False
# 4           4             False                False                 True
#
#    V201228_No Preference  V201228_Other  V201228_Refused  V201228_Republican  \
# 0                  False          False            False                True
# 1                  False           True            False               False
# 2                  False          False            False               False
# 3                  False          False            False                True
# 4                  False          False            False               False
#
# ...

# %%
x.dtypes
# Out:
# Unnamed: 0                                                                int64
# V201228_Democrat                                                           bool
# V201228_Do not know                                                        bool
# V201228_Independent                                                        bool
# V201228_No Preference                                                      bool
# V201228_Other                                                              bool
# V201228_Refused                                                            bool
# V201228_Republican                                                         bool
# V201228_error                                                              bool
# V202637_2                                                                  bool
# V202637_3                                                                  bool
# V202637_4                                                                  bool
# ...

# %%
y.dtypes
# Out:
# dtype('O')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=1)

# %%
scaler = StandardScaler()

# Fit the training data to the standard scaler
x_scaler = scaler.fit(x_train)

# Transform the training data using the scaler
x_train_scaled = x_scaler.transform(x_train)

# Transform the testing data using the scaler
x_test_scaled = x_scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(x_train, y_train)
#       4 y_pred = model.predict(x_test)
#
# File c:\Users\isabe\anaconda3\envs\dev\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\isabe\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
# ...

# %%
#print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_train, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 #print(classification_report(y_test, y_pred))
# ----> 2 accuracy = accuracy_score(y_train, y_pred)
#       3 print("Accuracy:", accuracy)
#
# File c:\Users\isabe\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
# ...
