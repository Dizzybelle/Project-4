# %%
# Import modules
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
#dropped missing data manually since pandas wasn't cooperating
vote_df = pd.read_csv(
    Path('C:/Users/isabe/OneDrive/Documents/GitHub/Project-4/for_lear.csv')   
)
vote_df.head()
# Out:
#    Unnamed: 0     V201228  V201507x  \
# 0           6  Republican        37
# 1          36    Democrat        71
# 2          41    Democrat        56
# 3          48  Republican        42
# 4          58  Republican        48
#
#                                             V201549x        V202468x  V202073  \
# 0                                White, non-Hispanic  $20,000-24,999        1
# 1                                Black, non-Hispanic  $45,000-49,999        0
# 2                                Black, non-Hispanic  $20,000-24,999        0
# 3  Asian or Native Hawaiian/other Pacific Islande...  $65,000-69,999        1
# 4                                White, non-Hispanic  $45,000-49,999        0
#
#         V201201  V201151  V201152
# 0  Conservative       50       75
# 1  Conservative       60       15
# 2  Conservative       80        5
# 3       Liberal       15       80
# 4  Conservative       60       30

# %%
x = vote_df.drop(columns=['V202073'])
y = vote_df['V202073']

# %%
x.head()
# Out:
#    Unnamed: 0     V201228  V201507x  \
# 0           6  Republican        37
# 1          36    Democrat        71
# 2          41    Democrat        56
# 3          48  Republican        42
# 4          58  Republican        48
#
#                                             V201549x        V202468x  \
# 0                                White, non-Hispanic  $20,000-24,999
# 1                                Black, non-Hispanic  $45,000-49,999
# 2                                Black, non-Hispanic  $20,000-24,999
# 3  Asian or Native Hawaiian/other Pacific Islande...  $65,000-69,999
# 4                                White, non-Hispanic  $45,000-49,999
#
#         V201201  V201151  V201152
# 0  Conservative       50       75
# 1  Conservative       60       15
# 2  Conservative       80        5
# 3       Liberal       15       80
# 4  Conservative       60       30

# %%
#y = y.drop(y[y == -1].index)
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: V202073, dtype: int64

# %%
x = pd.get_dummies(x)

# %%
x.head()
# Out:
#    Unnamed: 0  V201507x  V201151  V201152  V201228_Democrat  \
# 0           6        37       50       75             False
# 1          36        71       60       15              True
# 2          41        56       80        5              True
# 3          48        42       15       80             False
# 4          58        48       60       30             False
#
#    V201228_Independent  V201228_Other  V201228_Republican  \
# 0                False          False                True
# 1                False          False               False
# 2                False          False               False
# 3                False          False                True
# 4                False          False                True
#
#    V201549x_Asian or Native Hawaiian/other Pacific Islander, non-Hispanic  \
# 0                                              False
# 1                                              False
# 2                                              False
# ...

# %%
x.dtypes
# Out:
# Unnamed: 0                                                                int64
# V201507x                                                                  int64
# V201151                                                                   int64
# V201152                                                                   int64
# V201228_Democrat                                                           bool
# V201228_Independent                                                        bool
# V201228_Other                                                              bool
# V201228_Republican                                                         bool
# V201549x_Asian or Native Hawaiian/other Pacific Islander, non-Hispanic     bool
# V201549x_Black, non-Hispanic                                               bool
# V201549x_Hispanic                                                          bool
# V201549x_Multiple races, non-Hispanic                                      bool
# ...

# %%
y.dtypes
# Out:
# dtype('int64')

# %%
#optimize random state to get highest r2 we can.
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=20)

# %%
scaler = StandardScaler()

# Fit the training data to the standard scaler
x_scaler = scaler.fit(x_train)

# Transform the training data using the scaler
x_train_scaled = x_scaler.transform(x_train)

# Transform the testing data using the scaler
x_test_scaled = x_scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# c:\Users\isabe\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.7407407407407407
